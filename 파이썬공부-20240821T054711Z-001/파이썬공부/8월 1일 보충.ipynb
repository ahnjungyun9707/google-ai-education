# %%
n = int(input('숫자입력 : '))

total = 0
cnt = 0

while 0<=n<=100:
    total += n # n값을 계속 누적합
    cnt += 1 # 개수는 1씩 증가
    n = int(input('숫자입력 : '))

print(f'합 : {total}')
print(f'평균 : {total/cnt:.1f}')
# Out:
# 숫자입력 : 100
# 숫자입력 : 55
# 숫자입력 : 38
# 숫자입력 : 78
# 숫자입력 : 80
