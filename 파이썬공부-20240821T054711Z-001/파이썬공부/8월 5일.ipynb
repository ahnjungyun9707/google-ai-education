# %%
def plus_ten(x):
  return x+10

result = plus_ten(1)
print(result)
# Out:
# 11

# %%
plus_ten = lambda x:x+10

result = plus_ten(1)
print(result)
# Out:
# 11

# %%
import math
import time

# 시작시간 start변수에 저장
start = time.time()

# 수행시간을 측정하고자하는 대상 코트(로직)
math.factorial(100000)

# 종료시간 end변수에 저장
end = time.time()

# 소요된 시간
print(f"{end - start:.5f} sec")
# Out:
# 0.16082 sec

# %%
import math
import time

# 람다 함수 정의
plus_ten = lambda x:x+10
result = 0

# 시작시간 start변수에 저장
start = time.time()

# 수행시간을 측정하고자하는 대상 코트(로직)
for i in range(100000):
    result+=plus_ten(i)

# 종료시간 end변수에 저장
end = time.time()

# 소요된 시간
print(f"{end - start:.5f} sec")
# Out:
# 0.02787 sec

# %%
# %%timeit
math.factorial(100000)
# Out:
# 178 ms ± 31 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import sys

if __name__ == '__main__':
    print(sys.argv[0]) # main.py
    print(sys.argv[1]) # a
    print(sys.argv[2]) # b

# %% [markdown]
# Class

# %%
class Calculator:
  # __init___ 함수의 역할
  # 클래스 객체 생성시 호출되는 함수
    def __init__(self):
        self.result = 0
        self.op1 = 0
        self.op2 = 0
        #self.operation = '+'
        print("__init__이 호출되었음")

    # 클래스의 멤버 함수의 첫번째 인수는 무조건 self로 적어주자.
    # 클래스 안에 멤버 변수는 직접 변수 값을 설정할 수 없으므로
    # 멤버 함수를 통해 값을 설정해야한다.
    def inputValue(self, op1, op2):
        self.op1 = op1
        self.op2 = op2


    def add(self):
        self.result = self.op1 + self.op2
        print(self.result)

    # def diractAdd(self, op1, op2):
    #     self.op1 = op1
    #     self.op2 = op2
    #     self.result = self.op1 + self.op2
    #     print(self.result)

    def sub(self):
        self.result = self.op1 - self.op2
        return self.result

    def mul(self):
        self.result = self.op1 * self.op2
        return self.result

    def div(self):
        self.result = self.op1 / self.op2
        return self.result




# 클래스의 객체 cal1을 생성
# 생성시 __init___함수를 호출
cal1 = Calculator()

# add() 멤버함수 호출 전에 3, 10값음 세팅
cal1.inputValue(3,10)
result = cal1.add()
print("add result:{}".format(result))
result = cal1.sub()
print("sub result:{}".format(result))

#
# cal1.diractAdd(3,10)
# Out:
# __init__이 호출되었음
# 13
# add result:None
# sub result:-7

# %%
# 전역변수
temp = 123

def myTest():
  temp = 456
  print(temp)

myTest()
print(temp)
# Out:
# 456
# 123

# %%
# !pip install PyQt5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 20.5 MB/s eta 0:00:00
# ...

# %%
## Ex 3-1. 창 띄우기.

import sys
from PyQt5.QtWidgets import QApplication, QWidget


class MyApp(QWidget):

    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        self.setWindowTitle('My First Application')
        self.move(300, 300)
        self.resize(400, 200)
        self.show()


if __name__ == '__main__':
   app = QApplication(sys.argv)
   ex = MyApp()
   sys.exit(app.exec_())
